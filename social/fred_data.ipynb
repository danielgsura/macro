# %%
from fredapi import Fred
from datetime import datetime

# %%
fred = Fred(api_key='c91f3397df57fae05c12d4e199cfcbf5')

# %% [markdown]
# # Sample

# %%
start_date = datetime(2010, 1, 1)
end_date = datetime(2023, 2, 28)
data = fred.get_series('GDPC1', start_date, end_date)

# %%
import pandas as pd
df = pd.DataFrame(data, columns=['GDP'])

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data

# %%
data = fred.get_series('DTWEXBGS', start_date, end_date)
df = pd.DataFrame(data, columns=['DXY'])

# %%
df.fillna(method = "ffill", inplace = True)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.reset_index(inplace = True)
df
# Out:
#           index       DXY
# 0    2010-01-01       NaN
# 1    2010-01-04   92.3566
# 2    2010-01-05   92.2236
# 3    2010-01-06   92.0941
# 4    2010-01-07   92.3684
# ...         ...       ...
# 3426 2023-02-20  120.5898
# 3427 2023-02-21  120.6705
# 3428 2023-02-22  120.8904
# 3429 2023-02-23  121.1348
# 3430 2023-02-24  121.6304
#
# [3431 rows x 2 columns]

# %%
df.rename(columns = {'index': 'date'}, inplace = True)

# %%
df.to_excel('dollar_index.xlsx', index = False)
