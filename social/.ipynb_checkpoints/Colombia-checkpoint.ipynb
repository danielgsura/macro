# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import datetime as dt

# %% [markdown]
# # Data

# %% [markdown]
# ### Google

# %%
df_google = pd.read_csv('TermometroRsocial.csv')
df_google.head()
# Out:
#   Unnamed: 0  Unnamed: 1 Pais  level_1        date  /g/120ry1nd  isPartial  \
# 0         DO           0   DO        0  2010-01-01          0.0      False
# 1         DO           1   DO        1  2010-02-01         34.0      False
# 2         DO           2   DO        2  2010-03-01         39.0      False
# 3         DO           3   DO        3  2010-04-01         20.0      False
# 4         DO           4   DO        4  2010-05-01         53.0      False
#
#         log     cycle     trend
# 0 -4.605170 -4.589492 -0.015678
# 1  3.526361  2.918081  0.608279
# 2  3.663562  2.507817  1.155745
# 3  2.995732  1.396870  1.598863
# 4  3.970292  2.018720  1.951572

# %%
df_google_co = df_google[df_google['Pais'] == 'CO'][['date', '/g/120ry1nd','log','trend']].copy()
df_google_co.columns = ['date', 'risk_index', 'risk_log_index','risk_trend']
df_google_co.reset_index(drop = True, inplace = True)

# %%
type(df_google_co.at[0,'date'])
# Out:
# str

# %%
# group by month
df_google_co['date_m'] = pd.to_datetime(df_google_co['date']).dt.to_period('M')
df_google_co
# Out:
#            date  risk_index  risk_log_index  risk_trend   date_m
# 0    2010-01-01         4.0        1.386294    1.993325  2010-01
# 1    2010-02-01        12.0        2.484907    2.003520  2010-02
# 2    2010-03-01        10.0        2.302585    2.003598  2010-03
# 3    2010-04-01         8.0        2.079442    1.991465  2010-04
# 4    2010-05-01         9.0        2.197225    1.970009  2010-05
# ..          ...         ...             ...         ...      ...
# 153  2022-10-01        19.0        2.944439    2.881375  2022-10
# 154  2022-11-01        34.0        3.526361    2.893014  2022-11
# 155  2022-12-01         6.0        1.791759    2.905737  2022-12
# 156  2023-01-01        13.0        2.564949    2.933610  2023-01
# 157  2023-02-01        37.0        3.610918    2.972129  2023-02
#
# [158 rows x 5 columns]

# %%
df_google_co_m = df_google_co.groupby('date_m')[['risk_index', 'risk_log_index','risk_trend']].mean().reset_index()

# %% [markdown]
# ### EMBI

# %%
df_embi = pd.read_excel('embi.xlsx')
df_embi_co = df_embi[['Fecha', 'Colombia']].copy()
df_embi_co.columns = ['date', 'embi']
df_embi_co.head()
# Out:
#                   date     embi
# 0  2007-10-29 00:00:00  1.60120
# 1  2007-10-30 00:00:00  1.57447
# 2  2007-10-31 00:00:00  1.47853
# 3  2007-11-01 00:00:00  1.60699
# 4  2007-11-02 00:00:00  1.68363

# %%
df_embi_co['date_m'] = pd.to_datetime(df_embi_co['date']).dt.to_period('M')
df_embi_co
# Out:
#                      date     embi   date_m
# 0     2007-10-29 00:00:00  1.60120  2007-10
# 1     2007-10-30 00:00:00  1.57447  2007-10
# 2     2007-10-31 00:00:00  1.47853  2007-10
# 3     2007-11-01 00:00:00  1.60699  2007-11
# 4     2007-11-02 00:00:00  1.68363  2007-11
# ...                   ...      ...      ...
# 3827  2023-02-23 00:00:00  3.94760  2023-02
# 3828  2023-02-24 00:00:00  3.91042  2023-02
# 3829  2023-02-27 00:00:00  3.86666  2023-02
# 3830  2023-02-28 00:00:00  3.93189  2023-02
# 3831  2023-03-01 00:00:00  3.95376  2023-03
#
# [3832 rows x 3 columns]

# %%
df_embi_co_m = df_embi_co.groupby('date_m')[['embi']].mean().reset_index()
df_embi_co_m
# Out:
#       date_m      embi
# 0    2007-10  1.551400
# 1    2007-11  1.961907
# 2    2007-12  1.881167
# 3    2008-01  2.408224
# 4    2008-02  2.493140
# ..       ...       ...
# 181  2022-11  4.174174
# 182  2022-12  3.823606
# 183  2023-01  3.708017
# 184  2023-02  3.829981
# 185  2023-03  3.953760
#
# [186 rows x 2 columns]

# %% [markdown]
# ### FX

# %%
df_fx = pd.read_excel('tcs_yahoo.xlsx')
df_fx.drop(columns = ['Unnamed: 0'], inplace = True)
df_fx_co = df_fx[['date', 'FX_Colombia']]
df_fx_co.columns = ['date', 'fx']
df_fx_co.head()
# Out:
#         date       fx
# 0 2011-03-02  1917.25
# 1 2011-03-03  1906.00
# 2 2011-03-04  1889.00
# 3 2011-03-07  1895.00
# 4 2011-03-08  1889.00

# %%
df_fx_co['date_m'] = pd.to_datetime(df_fx_co['date']).dt.to_period('M')
df_fx_co_m = df_fx_co.groupby('date_m')[['fx']].mean().reset_index()
df_fx_co_m
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_27312\132101493.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fx_co['date_m'] = pd.to_datetime(df_fx_co['date']).dt.to_period('M')
#       date_m           fx
# 0    2011-03  1872.958692
# 1    2011-04  1800.084998
# 2    2011-05  1797.954351
# 3    2011-06  1774.315912
# 4    2011-07  1758.171427
# ..       ...          ...
# 140  2022-11  4916.799827
# 141  2022-12  4786.089910
# 142  2023-01  4709.914262
# 143  2023-02  4777.322949
# 144  2023-03  4808.524902
#
# [145 rows x 2 columns]

# %%
df_dollar = pd.read_excel('dollar_index.xlsx')
df_dollar['date_str'] = df_dollar['date'].astype(str)
df_dollar.head()
# Out:
#         date      DXY    date_str
# 0 2010-01-01      NaN  2010-01-01
# 1 2010-01-04  92.3566  2010-01-04
# 2 2010-01-05  92.2236  2010-01-05
# 3 2010-01-06  92.0941  2010-01-06
# 4 2010-01-07  92.3684  2010-01-07

# %%
df_dollar['date_m'] = pd.to_datetime(df_dollar['date']).dt.to_period('M')
df_dollar_m = df_dollar.groupby('date_m')[['DXY']].mean().reset_index()
df_dollar_m
# Out:
#       date_m         DXY
# 0    2010-01   92.406625
# 1    2010-02   94.039250
# 2    2010-03   93.149878
# 3    2010-04   92.639086
# 4    2010-05   95.567571
# ..       ...         ...
# 153  2022-10  127.399195
# 154  2022-11  124.759232
# 155  2022-12  122.191027
# 156  2023-01  119.819295
# 157  2023-02  120.206294
#
# [158 rows x 2 columns]

# %% [markdown]
# ### Inflacion

# %%
df_cpi = pd.read_excel('inflacion_col.xlsx')
df_cpi.head()
# Out:
#        fecha  inflacion
# 0 1993-01-01     0.2482
# 1 1993-02-01     0.2471
# 2 1993-03-01     0.2418
# 3 1993-04-01     0.2308
# 4 1993-05-01     0.2221

# %%
df_cpi['date_m'] = pd.to_datetime(df_cpi['fecha']).dt.to_period('M')
df_cpi_m = df_cpi.groupby('date_m')[['inflacion']].mean().reset_index()
df_cpi_m
# Out:
#       date_m  inflacion
# 0    1993-01     0.2482
# 1    1993-02     0.2471
# 2    1993-03     0.2418
# 3    1993-04     0.2308
# 4    1993-05     0.2221
# ..       ...        ...
# 356  2022-09     0.1144
# 357  2022-10     0.1222
# 358  2022-11     0.1253
# 359  2022-12     0.1312
# 360  2023-01     0.1325
#
# [361 rows x 2 columns]

# %% [markdown]
# # Wrangle

# %%
df_merge1 = df_google_co_m.merge(df_embi_co_m, how = 'inner', on='date_m')
df_merge2 = df_merge1.merge(df_fx_co_m, how = 'inner', on='date_m')
df_merge3 = df_merge2.merge(df_dollar_m, how = 'inner', on='date_m')
df_merge4 = df_merge3.merge(df_cpi_m, how = 'inner', on='date_m')
df_merge4
# Out:
#       date_m  risk_index  risk_log_index  risk_trend      embi           fx  \
# 0    2011-03        10.0        2.302585    1.985611  1.551506  1872.958692
# 1    2011-04         9.0        2.197225    2.006170  1.516137  1800.084998
# 2    2011-05        10.0        2.302585    2.015562  1.472593  1797.954351
# 3    2011-06         5.0        1.609438    2.016626  1.447030  1774.315912
# 4    2011-07         6.0        1.791759    2.016985  1.418823  1758.171427
# ..       ...         ...             ...         ...       ...          ...
# 138  2022-09        27.0        3.295837    2.867312  4.236795  4444.052827
# 139  2022-10        19.0        2.944439    2.881375  4.714402  4715.983352
# 140  2022-11        34.0        3.526361    2.893014  4.174174  4916.799827
# 141  2022-12         6.0        1.791759    2.905737  3.823606  4786.089910
# 142  2023-01        13.0        2.564949    2.933610  3.708017  4709.914262
#
#             DXY  inflacion
# 0     88.487226     0.0319
# 1     86.921367     0.0284
# 2     86.946682     0.0302
# 3     86.941255     0.0323
# 4     86.319876     0.0342
# ..          ...        ...
# 138  125.424432     0.1144
# 139  127.399195     0.1222
# 140  124.759232     0.1253
# 141  122.191027     0.1312
# 142  119.819295     0.1325
#
# [143 rows x 8 columns]

# %%
df_merge4['log_fx'] = np.log(df_merge4['fx'])
df_merge4['log_DXY'] = np.log(df_merge4['DXY'])
df_merge4.columns
# Out:
# Index(['date_m', 'risk_index', 'risk_log_index', 'risk_trend', 'embi', 'fx',
#        'DXY', 'inflacion', 'log_fx', 'log_DXY'],
#       dtype='object')

# %%
df_final = df_merge4[['date_m', 'risk_log_index', 'risk_trend', 'embi', 'inflacion', 'log_fx', 'log_DXY']]

# %%
df_final.to_excel('data_riesgo_social_col.xlsx')

# %% [markdown]
# # EDA

# %%
df_correl = df_final.corr()
plt.figure(figsize = (10,7))
sns.heatmap(df_correl, annot=True,cmap = 'coolwarm')
plt.title('Correlacion con indicador de riesgo')
plt.show()

# %%
sns.pairplot(df_final[[ 'log_fx', 'risk_trend', 'embi', 'inflacion',  'log_DXY']])
plt.show()

# %% [markdown]
# # Causality

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %%
df_final.columns
# Out:
# Index(['date_m', 'risk_log_index', 'risk_trend', 'embi', 'inflacion', 'log_fx',
#        'log_DXY'],
#       dtype='object')

# %%
data = df_final[['risk_trend', 'embi', 'inflacion', 'log_fx',
       'log_DXY']].copy()

# %%
gc_res = grangercausalitytests(data[['risk_trend', 'log_fx']], 4)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.1211  , p=0.1475  , df_denom=139, df_num=1
# ssr based chi2 test:   chi2=2.1668  , p=0.1410  , df=1
# likelihood ratio test: chi2=2.1505  , p=0.1425  , df=1
# parameter F test:         F=2.1211  , p=0.1475  , df_denom=139, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=9.5202  , p=0.0001  , df_denom=136, df_num=2
# ssr based chi2 test:   chi2=19.7405 , p=0.0001  , df=2
# likelihood ratio test: chi2=18.4754 , p=0.0001  , df=2
# parameter F test:         F=9.5202  , p=0.0001  , df_denom=136, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4448  , p=0.2326  , df_denom=133, df_num=3
# ssr based chi2 test:   chi2=4.5626  , p=0.2068  , df=3
# likelihood ratio test: chi2=4.4898  , p=0.2132  , df=3
# parameter F test:         F=1.4448  , p=0.2326  , df_denom=133, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.0671  , p=0.0888  , df_denom=130, df_num=4
# ssr based chi2 test:   chi2=8.8410  , p=0.0652  , df=4
# likelihood ratio test: chi2=8.5712  , p=0.0728  , df=4
# parameter F test:         F=2.0671  , p=0.0888  , df_denom=130, df_num=4

# %%
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# %%
maxlag = 12
test = 'ssr_chi2test'
grangers_causation_matrix(data, variables = data.columns)
# Out:
#               risk_trend_x  embi_x  inflacion_x  log_fx_x  log_DXY_x
# risk_trend_y        1.0000  0.0089       0.0056    0.0001     0.0046
# embi_y              0.0687  1.0000       0.0142    0.1430     0.0488
# inflacion_y         0.0129  0.0001       1.0000    0.0736     0.3326
# log_fx_y            0.0104  0.3057       0.1845    1.0000     0.0003
# log_DXY_y           0.0788  0.5855       0.0311    0.0273     1.0000

# %% [markdown]
# Assuming a significance level of 0.05, if the p-value is lesser than 0.05, then we do NOT reject the null hypothesis that X does NOT granger cause Y.
#
# If p-value <= $\alpha$, $x$ causes $y$
#
# * Risk trend causes fx
# * Risk trend causes inflation
# * Risk trend causes embi if $\alpha$ = 0.1
# * Embi does not cause fx
# * Inflation causes embi

# %% [markdown]
# # Lag order

# %%
data
# Out:
#      risk_trend      embi  inflacion    log_fx   log_DXY
# 0      1.985611  1.551506     0.0319  7.535275  4.482858
# 1      2.006170  1.516137     0.0284  7.495589  4.465004
# 2      2.015562  1.472593     0.0302  7.494405  4.465295
# 3      2.016626  1.447030     0.0323  7.481170  4.465233
# 4      2.016985  1.418823     0.0342  7.472030  4.458060
# ..          ...       ...        ...       ...       ...
# 138    2.867312  4.236795     0.1144  8.399322  4.831703
# 139    2.881375  4.714402     0.1222  8.458713  4.847325
# 140    2.893014  4.174174     0.1253  8.500413  4.826386
# 141    2.905737  3.823606     0.1312  8.473469  4.805586
# 142    2.933610  3.708017     0.1325  8.457425  4.785985
#
# [143 rows x 5 columns]

# %%
from statsmodels.tsa.api import VAR

# Generate random data
# Create VAR model object
model = VAR(data)
# Fit VAR model with lag order of 3
model_fitted = model.fit(3)


model_fitted.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 03, Mar, 2023
# Time:                     17:19:12
# --------------------------------------------------------------------
# No. of Equations:         5.00000    BIC:                   -39.7111
# Nobs:                     140.000    HQIC:                  -40.7090
# Log likelihood:           1984.19    FPE:                1.06126e-18
# AIC:                     -41.3921    Det(Omega_mle):     6.17790e-19
# --------------------------------------------------------------------
# Results for equation risk_trend
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.021982         0.040139            0.548           0.584
# L1.risk_trend         2.724380         0.036927           73.778           0.000
# L1.embi              -0.003969         0.002938           -1.351           0.177
# L1.inflacion         -0.343384         0.176299           -1.948           0.051
# L1.log_fx            -0.001228         0.020042           -0.061           0.951
# L1.log_DXY            0.077587         0.061941            1.253           0.210
# L2.risk_trend        -2.632694         0.072142          -36.493           0.000
# L2.embi              -0.002932         0.003805           -0.771           0.441
# L2.inflacion          0.300545         0.295397            1.017           0.309
# L2.log_fx             0.036589         0.024725            1.480           0.139
# L2.log_DXY           -0.053609         0.099503           -0.539           0.590
# L3.risk_trend         0.903760         0.037956           23.811           0.000
# L3.embi               0.001827         0.002814            0.649           0.516
# L3.inflacion          0.151136         0.180301            0.838           0.402
# L3.log_fx             0.000901         0.019702            0.046           0.964
# L3.log_DXY           -0.086163         0.066745           -1.291           0.197
# ================================================================================
#
# Results for equation embi
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                -0.386190         1.680731           -0.230           0.818
# L1.risk_trend        -1.008361         1.546244           -0.652           0.514
# L1.embi               0.862655         0.123005            7.013           0.000
# L1.inflacion         15.943324         7.382238            2.160           0.031
# L1.log_fx             0.099619         0.839216            0.119           0.906
# L1.log_DXY            6.163882         2.593673            2.377           0.017
# L2.risk_trend         0.875087         3.020803            0.290           0.772
# L2.embi              -0.212686         0.159315           -1.335           0.182
# L2.inflacion        -16.345253        12.369227           -1.321           0.186
# L2.log_fx             0.248981         1.035315            0.240           0.810
# L2.log_DXY           -7.981079         4.166523           -1.916           0.055
# L3.risk_trend         0.181169         1.589326            0.114           0.909
# L3.embi               0.138134         0.117818            1.172           0.241
# L3.inflacion          2.844528         7.549794            0.377           0.706
# L3.log_fx             0.142248         0.824999            0.172           0.863
# L3.log_DXY            1.124332         2.794822            0.402           0.687
# ================================================================================
#
# Results for equation inflacion
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.043419         0.020478            2.120           0.034
# L1.risk_trend         0.010054         0.018839            0.534           0.594
# L1.embi               0.000854         0.001499            0.570           0.569
# L1.inflacion          1.407036         0.089944           15.643           0.000
# L1.log_fx             0.009232         0.010225            0.903           0.367
# L1.log_DXY            0.017896         0.031601            0.566           0.571
# L2.risk_trend        -0.013402         0.036805           -0.364           0.716
# L2.embi              -0.001871         0.001941           -0.964           0.335
# L2.inflacion         -0.365558         0.150705           -2.426           0.015
# L2.log_fx             0.012765         0.012614            1.012           0.312
# L2.log_DXY           -0.048043         0.050764           -0.946           0.344
# L3.risk_trend         0.003189         0.019364            0.165           0.869
# L3.embi               0.002457         0.001435            1.712           0.087
# L3.inflacion         -0.073613         0.091986           -0.800           0.424
# L3.log_fx            -0.014213         0.010052           -1.414           0.157
# L3.log_DXY            0.007385         0.034052            0.217           0.828
# ================================================================================
#
# Results for equation log_fx
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                -0.473180         0.238617           -1.983           0.047
# L1.risk_trend        -0.045004         0.219524           -0.205           0.838
# L1.embi               0.000082         0.017463            0.005           0.996
# L1.inflacion          2.605998         1.048074            2.486           0.013
# L1.log_fx             0.633057         0.119145            5.313           0.000
# L1.log_DXY            1.318913         0.368230            3.582           0.000
# L2.risk_trend         0.054900         0.428870            0.128           0.898
# L2.embi              -0.015178         0.022618           -0.671           0.502
# L2.inflacion         -3.065393         1.756088           -1.746           0.081
# L2.log_fx             0.176421         0.146986            1.200           0.230
# L2.log_DXY           -1.048514         0.591531           -1.773           0.076
# L3.risk_trend         0.026105         0.225640            0.116           0.908
# L3.embi               0.015037         0.016727            0.899           0.369
# L3.inflacion          0.564560         1.071862            0.527           0.598
# L3.log_fx             0.030346         0.117127            0.259           0.796
# L3.log_DXY            0.084970         0.396787            0.214           0.830
# ================================================================================
#
# Results for equation log_DXY
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.030254         0.076932            0.393           0.694
# L1.risk_trend         0.005986         0.070776            0.085           0.933
# L1.embi              -0.001041         0.005630           -0.185           0.853
# L1.inflacion          0.483642         0.337906            1.431           0.152
# L1.log_fx            -0.084068         0.038413           -2.189           0.029
# L1.log_DXY            1.534162         0.118720           12.923           0.000
# L2.risk_trend        -0.035997         0.138271           -0.260           0.795
# L2.embi              -0.008030         0.007292           -1.101           0.271
# L2.inflacion         -0.189123         0.566175           -0.334           0.738
# L2.log_fx             0.086311         0.047389            1.821           0.069
# L2.log_DXY           -0.608148         0.190714           -3.189           0.001
# L3.risk_trend         0.028728         0.072748            0.395           0.693
# L3.embi               0.001332         0.005393            0.247           0.805
# L3.inflacion         -0.161131         0.345576           -0.466           0.641
# L3.log_fx             0.013301         0.037763            0.352           0.725
# L3.log_DXY            0.044579         0.127927            0.348           0.727
# ================================================================================
#
# Correlation matrix of residuals
#               risk_trend      embi  inflacion    log_fx   log_DXY
# risk_trend      1.000000 -0.050729  -0.059674 -0.068053 -0.065862
# embi           -0.050729  1.000000   0.173666  0.613617  0.600099
# inflacion      -0.059674  0.173666   1.000000  0.141256  0.130915
# log_fx         -0.068053  0.613617   0.141256  1.000000  0.562615
# log_DXY        -0.065862  0.600099   0.130915  0.562615  1.000000

# %%
model_fitted.plot_acorr()

# %%
#forecast
fig = model_fitted.plot_forecast(10)
ax = fig.axes[0]
ax.legend(loc='upper left')
ax = fig.axes[1]
ax.legend(loc='upper left')
fig.tight_layout()
plt.show()
